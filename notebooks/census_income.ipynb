# %%
from collections import defaultdict
import sys
sys.path.append('..')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from utils.loss import MultiTaskLoss

# %%
data_path = '../data'
dataset = datasets.fetch_openml(
    'adult-census', return_X_y=True, data_home=data_path
)
df_features, df_target = dataset
df = pd.concat([df_features, df_target], axis=1)
feature_cols = [f.replace(':','').replace('-','.') for f in df_features.columns]
df.columns = feature_cols + ['income']
del dataset, df_features, df_target

# %%
df
# Out:
#         age         workclass    fnlwgt   education  education.num  \
# 0      39.0         State-gov   77516.0   Bachelors           13.0
# 1      50.0  Self-emp-not-inc   83311.0   Bachelors           13.0
# 2      38.0           Private  215646.0     HS-grad            9.0
# 3      53.0           Private  234721.0        11th            7.0
# 4      28.0           Private  338409.0   Bachelors           13.0
# ...     ...               ...       ...         ...            ...
# 32556  27.0           Private  257302.0  Assoc-acdm           12.0
# 32557  40.0           Private  154374.0     HS-grad            9.0
# 32558  58.0           Private  151910.0     HS-grad            9.0
# 32559  22.0           Private  201490.0     HS-grad            9.0
# 32560  52.0      Self-emp-inc  287927.0     HS-grad            9.0
#
#            marital.status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...
